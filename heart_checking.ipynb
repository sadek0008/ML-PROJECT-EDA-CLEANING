# %%
import pandas as pd 
import numpy as numpy
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv('heart.csv')

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  ...  MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0     40   M           ATA        140          289  ...    172              N      0.0       Up             0
# 1     49   F           NAP        160          180  ...    156              N      1.0     Flat             1
# 2     37   M           ATA        130          283  ...     98              N      0.0       Up             0
# 3     48   F           ASY        138          214  ...    108              Y      1.5     Flat             1
# 4     54   M           NAP        150          195  ...    122              N      0.0       Up             0
# ..   ...  ..           ...        ...          ...  ...    ...            ...      ...      ...           ...
# 913   45   M            TA        110          264  ...    132              N      1.2     Flat             1
# 914   68   M           ASY        144          193  ...    141              N      3.4     Flat             1
# 915   57   M           ASY        130          131  ...    115              Y      1.2     Flat             1
# 916   57   F           ATA        130          236  ...    174              N      0.0     Flat             1
# 917   38   M           NAP        138          175  ...    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %% [markdown]
# ## EDA

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR     Oldpeak  HeartDisease
# count  918.000000  918.000000   918.000000  918.000000  918.000000  918.000000    918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368    0.887364      0.553377
# std      9.432617   18.514154   109.384145    0.423046   25.460334    1.066570      0.497414
# min     28.000000    0.000000     0.000000    0.000000   60.000000   -2.600000      0.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000    0.000000      0.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000    0.600000      1.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000    1.500000      1.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000    6.200000      1.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['HeartDisease'].value_counts()
# Out:
# HeartDisease
# 1    508
# 0    410
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
def plotting(var,num):
    plt.subplot(2,2,num) 
    sns.histplot(df[var])
plotting('Age',1)
plotting('RestingBP',2)
plotting('Cholesterol',3)
plotting('MaxHR',4)

plt.tight_layout()

# %%
df['Cholesterol'].value_counts()
# Out:
# Cholesterol
# 0      172
# 254     11
# 220     10
# 223     10
# 204      9
#       ...
# 353      1
# 278      1
# 157      1
# 176      1
# 131      1
# Name: count, Length: 222, dtype: int64

# %%
ch_mean=df.loc[df['Cholesterol']!=0,'Cholesterol'].mean()

# %% [markdown]
# ch_mean

# %%
ch_mean
# Out:
# np.float64(244.6353887399464)

# %%
df['Cholesterol']=df['Cholesterol'].replace(0,ch_mean)
df['Cholesterol']=df['Cholesterol'].round(2)

# %%
rs_mean=df.loc[df['RestingBP']!=0,'RestingBP'].mean()
df['RestingBP']=df['RestingBP'].replace(0,ch_mean)
df['RestingBP']=df['RestingBP'].round(2)

# %%
def plotting(var,num):
    plt.subplot(2,2,num) 
    sns.histplot(df[var])
plotting('Age',1)
plotting('RestingBP',2)
plotting('Cholesterol',3)
plotting('MaxHR',4)

plt.tight_layout()

# %%
sns.countplot(x = df['Sex'],hue = df['HeartDisease'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x = df['FastingBS'],hue = df['HeartDisease'])
# Out:
# <Axes: xlabel='FastingBS', ylabel='count'>

# %%
sns.countplot(x = df['ChestPainType'],hue = df['HeartDisease'])
# Out:
# <Axes: xlabel='ChestPainType', ylabel='count'>

# %%
sns.boxplot(x = 'HeartDisease', y = 'Cholesterol',data = df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %%
sns.violinplot(x='HeartDisease', y='Age', data=df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
df_encode = pd.get_dummies(df,drop_first=True)

# %%
df_encode
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  ...  RestingECG_ST  ExerciseAngina_Y  ST_Slope_Flat  ST_Slope_Up
# 0     40      140.0        289.0          0  ...          False             False          False         True
# 1     49      160.0        180.0          0  ...          False             False           True        False
# 2     37      130.0        283.0          0  ...           True             False          False         True
# 3     48      138.0        214.0          0  ...          False              True           True        False
# 4     54      150.0        195.0          0  ...          False             False          False         True
# ..   ...        ...          ...        ...  ...            ...               ...            ...          ...
# 913   45      110.0        264.0          0  ...          False             False           True        False
# 914   68      144.0        193.0          1  ...          False             False           True        False
# 915   57      130.0        131.0          0  ...          False              True           True        False
# 916   57      130.0        236.0          0  ...          False             False           True        False
# 917   38      138.0        175.0          0  ...          False             False          False         True
#
# [918 rows x 16 columns]

# %%
df_encode = df_encode.astype(int)
